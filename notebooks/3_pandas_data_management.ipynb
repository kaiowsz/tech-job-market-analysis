# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
df_original = df.copy()

df_altered = df_original

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
# calculating the median salary
median_salary = df_altered['salary_year_avg'].median()

# filling missing values with median salary
df_altered['salary_year_avg'] = df_altered.loc[:,'salary_year_avg'].fillna(median_salary)

df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                2338967825360
# ID of df_altered:                 2338967825360
# Are the two dataframes the same?  True

# %%
# Calculating the median salary
median_salary = df_altered['salary_year_avg'].median()

# Filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df.sample(n=5)
# Out:
#        job_title_short            job_title      job_location  \
# 334722   Data Engineer    Data Engineer III      Bellevue, WA
# 79775    Data Engineer   Lead Data Engineer    Cincinnati, OH
# 309999    Data Analyst  IT cum Data Analyst         Singapore
# 108610    Data Analyst         Data Analyst  Lisbon, Portugal
# 35131    Data Engineer        Data Engineer      Bradford, UK
#
#                     job_via job_schedule_type  job_work_from_home  \
# 334722         via The Muse         Full-time               False
# 79775     via CareerBuilder         Full-time               False
# 309999  via BeBee Singapore        Contractor               False
# 108610         via WhatJobs         Full-time               False
# 35131         via WANE Jobs         Full-time               False
#
#                search_location     job_posted_date  job_no_degree_mention  \
# 334722  Florida, United States 2023-05-11 23:17:51                  False
# 79775     Texas, United States 2023-02-20 00:09:17                  False
# 309999               Singapore 2023-12-28 17:30:59                  False
# 108610                Portugal 2023-01-07 00:29:26                  False
# 35131           United Kingdom 2023-07-31 14:00:46                   True
#
#         job_health_insurance     job_country salary_rate  salary_year_avg  \
# 334722                  True   United States         NaN              NaN
# 79775                   True   United States         NaN              NaN
# 309999                 False       Singapore         NaN              NaN
# 108610                 False        Portugal         NaN              NaN
# 35131                  False  United Kingdom         NaN              NaN
#
#         salary_hour_avg                   company_name  \
# 334722              NaN                          Chewy
# 79775               NaN                    Capital One
# 309999              NaN  Lih Ming Construction Pte Ltd
# 108610              NaN                       Randstad
# 35131               NaN  Fruition IT Resources Limited
#
#                                                job_skills  \
# 334722  ['sql', 'python', 'ruby', 'ruby', 'java', 'ela...
# 79775   ['java', 'scala', 'python', 'nosql', 'sql', 'm...
# 309999      ['sql', 'python', 'r', 'tableau', 'power bi']
# 108610                                            ['sql']
# 35131                                                 NaN
#
#                                           job_type_skills
# 334722  {'cloud': ['aws', 'redshift'], 'databases': ['...
# 79775   {'cloud': ['redshift', 'snowflake', 'aws', 'az...
# 309999  {'analyst_tools': ['tableau', 'power bi'], 'pr...
# 108610                           {'programming': ['sql']}
# 35131                                                 NaN

# %%
# getting 10% of the actual data (rows in this case)

df.sample(frac=0.1, replace=False)
# Out:
#               job_title_short                                       job_title  \
# 206488         Data Scientist                                  Data Scientist
# 380924           Data Analyst     Head of Data Analytics and Digital Insights
# 405566  Senior Data Scientist                           Senior Data Scientist
# 217548          Data Engineer               Data Engineer Wasserkraft (w/m/d)
# 509175           Data Analyst                           Business Data Analyst
# ...                       ...                                             ...
# 426369      Software Engineer  Software Development Engineer in Test for Data
# 415759         Data Scientist                                  data scientist
# 182003         Data Scientist                                  Data Scientist
# 654520         Data Scientist                            Meteo Data Scientist
# 734903          Data Engineer                             Azure Data Engineer
#
#                         job_location          job_via  \
# 206488                     Tampa, FL        via BeBee
# 380924  Dubai - United Arab Emirates        via BeBee
# 405566                      Anywhere     via LinkedIn
# 217548               Vienna, Austria         via XING
# 509175                Alpharetta, GA        via BeBee
# ...                              ...              ...
# 426369     Minato City, Tokyo, Japan        via BeBee
# 415759                   Atlanta, GA  via Trabajo.org
# 182003                    Irving, TX  via Jobgigy.com
# 654520               Prague, Czechia     via LinkedIn
# 734903                Espoo, Finland  via Trabajo.org
#
#                job_schedule_type  job_work_from_home         search_location  \
# 206488                 Full-time               False  Florida, United States
# 380924                 Full-time               False    United Arab Emirates
# 405566                 Full-time                True    Texas, United States
# 217548                 Full-time               False                 Austria
# 509175                 Full-time               False                 Georgia
# ...                          ...                 ...                     ...
# 426369                 Full-time               False                   Japan
# 415759  Full-time and Contractor               False                 Georgia
# 182003                 Full-time               False                   Sudan
# 654520                 Full-time               False                 Czechia
# 734903                 Full-time               False                 Finland
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 206488 2023-03-25 22:06:40                  False                 False
# 380924 2023-02-06 18:48:12                   True                 False
# 405566 2023-11-13 16:04:05                  False                 False
# 217548 2023-02-01 23:07:24                   True                 False
# 509175 2023-09-14 11:31:55                  False                  True
# ...                    ...                    ...                   ...
# 426369 2023-07-22 16:31:50                   True                 False
# 415759 2023-10-20 16:49:09                  False                  True
# 182003 2023-03-06 16:19:59                  False                 False
# 654520 2023-04-05 10:31:28                  False                 False
# 734903 2023-08-13 21:28:48                  False                 False
#
#                  job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 206488         United States         NaN              NaN              NaN
# 380924  United Arab Emirates         NaN              NaN              NaN
# 405566         United States         NaN              NaN              NaN
# 217548               Austria         NaN              NaN              NaN
# 509175         United States         NaN              NaN              NaN
# ...                      ...         ...              ...              ...
# 426369                 Japan         NaN              NaN              NaN
# 415759         United States         NaN              NaN              NaN
# 182003                 Sudan         NaN              NaN              NaN
# 654520               Czechia         NaN              NaN              NaN
# 734903               Finland         NaN              NaN              NaN
#
#                  company_name  \
# 206488         Ascendion Inc.
# 380924  Emagine Solutions FZE
# 405566            StormImpact
# 217548             VERBUND AG
# 509175       Aditi Consulting
# ...                       ...
# 426369                 PayPay
# 415759               Randstad
# 182003                Epsilon
# 654520           Ezpada Group
# 734903     Innofactor Finland
#
#                                                job_skills  \
# 206488            ['sql', 'aws', 'snowflake', 'power bi']
# 380924                                                NaN
# 405566             ['r', 'python', 'sql', 'linux', 'git']
# 217548  ['sql', 'java', 'python', 'javascript', 'azure...
# 509175  ['sql', 'python', 'r', 'java', 'sql server', '...
# ...                                                   ...
# 426369                                ['sql', 'selenium']
# 415759                                                NaN
# 182003  ['python', 't-sql', 'azure', 'databricks', 'sp...
# 654520     ['sql', 'python', 'r', 'matlab', 'matplotlib']
# 734903  ['sql', 't-sql', 'sql server', 'azure', 'datab...
#
#                                           job_type_skills
# 206488  {'analyst_tools': ['power bi'], 'cloud': ['aws...
# 380924                                                NaN
# 405566  {'os': ['linux'], 'other': ['git'], 'programmi...
# 217548  {'cloud': ['azure'], 'libraries': ['spark'], '...
# 509175  {'analyst_tools': ['tableau', 'looker', 'qlik'...
# ...                                                   ...
# 426369  {'libraries': ['selenium'], 'programming': ['s...
# 415759                                                NaN
# 182003  {'cloud': ['azure', 'databricks'], 'libraries'...
# 654520  {'libraries': ['matplotlib'], 'programming': [...
# 734903  {'cloud': ['azure', 'databricks', 'snowflake']...
#
# [78574 rows x 17 columns]
